# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_csv_path = R"C:\Users\akuzansk\OneDrive - Hexagon\Desktop\Praca\magisterska\inputData\training\wanted_lane_departure\1.csv"

# %%
csv_data = pd.read_csv(data_csv_path)

# %%
csv_data
# Out:
#      state  distance_to_left  distance_to_right  delta_left_lane  \
# 0        0        162.909691         127.760172         0.000000
# 1        0        163.223412         130.730212         0.313721
# 2        0        163.122343         130.789935         0.212652
# 3        0        162.369682         131.449228        -0.540008
# 4        0        161.743497         132.042840        -1.058444
# ..     ...               ...                ...              ...
# 278      0        176.998284         138.689624        -1.547397
# 279      0        175.710379         138.379050        -1.205046
# 280      0        175.376911         140.523529        -0.525404
# 281      0        175.745435         140.947908         0.080697
# 282      0        176.394428         141.447963         0.437356
#
#      delta_right_lane
# 0            0.000000
# 1            2.970040
# 2            3.029763
# 3            3.689056
# 4            2.238119
# ..                ...
# ...

# %%
csv_data.plot()
# Out:
# <AxesSubplot: >

# %%
csv_data[["distance_to_left", "distance_to_right"]].plot()
# Out:
# <AxesSubplot: >

# %%
fig, ax1 = plt.subplots()

# Plot the distance to left on the first y-axis
ax1.plot(csv_data[['distance_to_left', 'distance_to_right']])
ax1.set_xlabel('Index')
ax1.set_ylabel('Distance to Left (units)', color='blue')

# Create a second y-axis that shares the same x-axis with the first axis
ax2 = ax1.twinx()

# Plot the state on the second y-axis
ax2.plot(csv_data['state'], color='red')
ax2.set_ylabel('State', color='red')

# csv_data[["delta_left_lane", "delta_right_lane"]].plot()
# csv_data[["state"]].plot(secondary_y=True)
# Out:
# Text(0, 0.5, 'State')

# %%
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrame
df = csv_data

# Create a figure and axis objects
fig, ax1 = plt.subplots()

# Plot the distance to left on the first y-axis
ax1.plot(csv_data[['distance_to_left', 'distance_to_right']])
ax1.set_xlabel('Index')
ax1.set_ylabel('Distance to Left (units)', color='blue')

# Create a second y-axis that shares the same x-axis with the first axis
ax2 = ax1.twinx()

# Plot the state on the second y-axis
ax2.plot(df['state'], color='red')
ax2.set_ylabel('State', color='red')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrame
df = csv_data

# Create a figure and axis objects
fig, ax1 = plt.subplots()

# Plot the distance to left on the first y-axis
ax1.plot(csv_data[['delta_left_lane', 'delta_right_lane']])
ax1.set_xlabel('Index')
ax1.set_ylabel('Distance to Left (units)', color='blue')

# Create a second y-axis that shares the same x-axis with the first axis
ax2 = ax1.twinx()

# Plot the state on the second y-axis
ax2.plot(df['state'], color='red')
ax2.set_ylabel('State', color='red')

# Show the plot
plt.show()
